# %%
print("Начинаем вторую тему")

# %% [markdown]
# #Повторение пройденного

# %% [markdown]
# 1. Вызов команды print() с пустыми скобками делает перевод строки.
#
# Приведённый ниже код:
# ```
# print('Python')
# print()
# print('C#')
# print('Java')
# print()
# print('JavaScript')
# ```
# выводит:
# ```
# Python
#
# C#
# Java
#
# JavaScript
# ```
# 2. Последовательность символов \n называется управляющей последовательностью и задаёт перевод строки.
#
# Приведённый ниже код:
# ```
# print('a', '\n', 'b', '\n', 'c', sep='*', end='#')
# ```
# выводит:
# ```
# a*
# *b*
# *c#
# ```
# 3. Параметры sep и end можно устанавливать одновременно.
#
# Приведённый ниже код:
# ```
# print('a', 'b', 'c', sep='*', end='finish')
# ```
# выводит:
# ```
# a*b*cfinish
# ```
# 4. Для разных команд print() можно задавать разные параметры sep и end.
#
# Приведённый ниже код:
# ```
# arg1 = 'Hello'
# sep1 = '_-_'
# end2 = '+++'
#
# print(arg1, 'everyone', sep=sep1, end='! ')
# print('How', 'are', 'you', 'in', '2024?', sep=' ', end=end2)
# ```
# выводит:
# ```
# Hello_-_everyone! How are you in 2024?+++
# ```
# 5. Чтобы убрать все дополнительные выводимые символы, можно установить параметры sep и end команды print() как пустые строки ('').
#
# Приведённый ниже код:
# ```
# print('a', 'b', 'c', sep='', end='')
# print('d', 'e', 'f', sep='', end='')
# ```
# выводит:
# ```
# abcdef
# ```
# 6. Если после вывода данных нужно более одного перевода строки, то можно использовать следующий код:
# ```
# print('Python', end='\n\n\n')
# ```
# 7. Параметр sep является разделителем для нескольких аргументов в команде print().
#
# Если аргумент в команде print() только один, то параметру sep нечего разделять. В таком случае параметр sep никак не будет влиять на выводимый текст.
#
# Приведённый ниже код:
# ```
# print('Python', sep='777')
# ```
# выводит:
# ```
# Python
# ```

# %% [markdown]
# #Типы данных

# %% [markdown]
#
# int  ---         5, -3,  0
# float  ---       4.5,  0.5, -1.2
#  complex  ---     complex(2+ 3j)
#  string   --- 'Это строка' "и это строка"
#  boolean --- True False

# %%
a=complex(2+ 3j)
print(type(a))
# Out:
# <class 'complex'>

# %% [markdown]
# # Целые числа

# %% [markdown]
# ## Основные операции с числами

# %%
a=int(input())
b=a//10
c=a%10
b+c
# Out:
# 67
# 13

# %% [markdown]
# 1.   ` + - * / ** // %`
# 2.   Порядок выполнения операций в Python аналогичен порядку выполнения операций, которые вы изучали на уроках математики.
#
# Таблица приоритетов арифметических операторов в Python приведена ниже (чем ниже расположен оператор в таблице, тем ниже его приоритет).
#
# Оператор |	Описание
# ---------|----------
# ()	     |Скобки
# **	     |Возведение в степень
# |-       |Унарный минус
# *, /, //, %	|Умножение, деление, целочисленное деление, остаток от деления
# +, -	|Сложение, вычитание

# %%
num1 = 100**200

print(num1)
# Out:
# ...

# %% [markdown]
# ## Возведение в степень

# %% [markdown]
# Для возведения числа в степень используется оператор **.
#
# Приведённый ниже код:
# ```
# print(2 ** 0)
# print(2 ** 1)
# print(2 ** 2)
# print(2 ** 3)
# print(2 ** (-1))
# ```
# выводит:
# ```
# 1
# 2
# 4
# 8
# 0.5
# ```
# Обратите внимание: оператор возведения в степень (**) может возводить не только в положительную степень, но и в отрицательную. Аналогично, основание степени  также может быть числом отрицательным.
#
# Приведённый ниже код:
# ```
# print(2**(-2))
# print((-3)**3)
# ```
# выводит:
# ```
# 0.25
# -27
# ```
#
# Обратите внимание: оператор возведения в степень (**) является правоассоциативным (значение выражения вычисляется справа налево) в соответствии с правилами математики. Таким образом, выражение x ** y ** z вычисляется как x ** (y ** z).
#
# Приведённый ниже код:
# ```
# print(2 ** 2 ** 3)     # 2 ** (2 ** 3) = 2 ** 8
# ```
# выводит:
# ```
# 256
# ```

# %% [markdown]
# ### Целочисленное деление

# %% [markdown]
# Для положительных чисел оператор целочисленного деления ведёт себя как обычное деление, за исключением того, что он отбрасывает десятичную часть результата.
#
# Приведённый ниже код:
# ```
# print(10 // 3)
# print(10 // 4)
# print(10 // 5)
# print(10 // 6)
# print(10 // 12)
# ```
# выводит:
# ```
# 3
# 2
# 2
# 1
# 0
# ```
# При делении отрицательных чисел необходимо помнить, что результат целочисленного деления округляется всегда в меньшую сторону.
#
# Приведённый ниже код:
# ```
# print(10 // 3)
# print(-10 // 3)
# ```
# выводит:
# ```
# 3     # округление в меньшую сторону
# -4    # округление в меньшую сторону
# ```

# %% [markdown]
# ## Деление с остатком

# %% [markdown]
# Оператор деления с остатком (%) возвращает остаток от деления двух целых чисел. Рассмотрим работу данного оператора на примерах.
#
# Приведённый ниже код:
# ```
# print(10 % 3)
# print(10 % 4)
# print(10 % 5)
# print(10 % 6)
# print(10 % 12)
# print(10 % 20)
# ```
# выводит:
# ```
# 1
# 2
# 0
# 4
# 10
# 10
# ```
# Запомни: при нахождении остатка от деления на целое число n может получаться результат 0,1,2,…n −1. Например, при делении на 2 возможны остатки 0,1, при делении на 3 возможны остатки 0,1,2 и т.д.

# %% [markdown]
# ## Обработка цифр числа

# %% [markdown]
# При помощи операции нахождения остатка и целочисленного деления можно достаточно несложно вычислить любую цифру числа.
#
# Последняя цифра числа определяется всегда как остаток от деления числа на 10 (% 10). Чтобы отщепить последнюю цифру от числа, необходимо разделить его нацело на 10 (// 10)

# %% [markdown]
# ## Преобразование  к числу с плавающей точкой

# %% [markdown]
# Для преобразования строки к числу с плавающей точкой мы используем команду float():
#
# num = float(input()) # преобразование считанной строки в число с плавающей точкой
#
# Обратите внимание, что преобразование чисел с плавающей точкой в целое производится с округлением в сторону нуля, то есть int(1.7) = 1, int(-1.7) = -1.

# %% [markdown]
# # Задания ⌨
#
#
# ---

# %% [markdown]
# **Задача 1:** Напишите программу, которая запрашивает у пользователя целое число и выводит его квадрат и куб.

# %% [markdown]
# **Задача 2:**![image.png](data:image/png;base64,...)

# %% [markdown]
# **Задача 3:** Напишите программу вывода на экран трех последовательно идущих чисел, каждое на отдельной строке. Первое число вводит пользователь, остальные числа вычисляются в программе.

# %% [markdown]
# **Задача 4:** Напишите программу, вычисляющую объём куба и площадь его полной поверхности по введённому значению длины ребра.

# %% [markdown]
# **Задача 5:** Напишите программу вычисления значения функции по введеным целым значениям a и b
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Задача 6:**Напишите программу, которая считывает целое число, после чего на экран выводится следующее и предыдущее целое число с пояснительным текстом.
# Пример при вводе 20:
# Следующее за числом 20 число: 21
# Для числа 20 предыдущее число: 19

# %% [markdown]
# **Задача 7:** Напишите программу, которая считает стоимость трех компьютеров, состоящих из монитора, системного блока, клавиатуры и мыши.
#
# Формат входных данных
# На вход программе подаётся четыре целых числа, каждое на отдельной строке. В первой строке — стоимость монитора, во второй строке — стоимость системного блока, в третьей строке — стоимость клавиатуры и в четвертой строке — стоимость мыши.
#
# Формат выходных данных
# Программа должна вывести одно число – стоимость покупки (трех компьютеров).

# %% [markdown]
# **Задача 8:** Напишите программу, которая считывает целое положительное число x и выводит на экран последовательность чисел x,2x,3x,4x и 5x, разделённых тремя черточками.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Задача 9:** Арифметическая прогрессия
#
# Арифметической прогрессией называется последовательность чисел, каждое из которых, начиная со 2-го , получается из предыдущего путем прибавления к нему одного и того же постоянного числа d (разность прогрессии). Если известен первый член прогрессии (a1) и её разность (d), то n-ый член арифметической прогрессии находится по формуле:
#
# ![image.png](data:image/png;base64,...)
#
# Входные данные.
# На вход программе подаются три целых числа: a1, d и n, каждое на отдельной строке.
#
# Выходные данные. Программа должна вывести n-ый член арифметической прогрессии.

# %% [markdown]
# **Задача 10:** Напишите программу, которая находит полное число метров по заданному числу сантиметров.

# %% [markdown]
# **Задача 11:** Безумный титан Танос собрал все 6 камней бесконечности и намеревается уничтожить половину населения Вселенной по щелчку пальцев. При этом если население Вселенной является нечетным числом, то титан проявит милосердие и округлит количество выживших в большую сторону. Помогите Мстителям подсчитать количество выживших.

# %% [markdown]
# **Задача 12:** Напишите программу для пересчёта величины временного интервала, заданного в секундах, в величину, выраженную в часах, минутах и секундах.

# %% [markdown]
# **Задача 13:** Напишите программу получения цифр трёхзначного числа:

# %% [markdown]
# Задача 14: Напишите программу, в которой рассчитывается сумма цифр двузначного числа.

# %% [markdown]
# Задача 15: Напишите программу, которая печатает число, образованное при перестановке цифр двузначного числа

# %% [markdown]
# **Задача 16:** Напишите программу, в которой рассчитывается сумма и произведение цифр положительного трёхзначного числа

# %% [markdown]
# **Задача 17:** Дано трехзначное число *abc*, в котором все цифры различны. Напишите программу, которая выводит шесть чисел, образованных при перестановке цифр заданного числа.
#
# Программа должна вывести шесть чисел, образованных при перестановке цифр заданного числа в следующем порядке:
# abc,acb,bac,bca,cab,cba.

# %% [markdown]
# **Задача 18:** Напишите программу, которая считывает длины двух катетов в прямоугольном треугольнике и выводит его площадь.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Задача 19**: Две старушки идут навстречу друг другу с постоянными скоростями V1 и V2
#   км/ч. Определите, через какое время (в часах) старушки встретятся, если расстояние между ними равно S км.
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Задача 20:** У известного американского писателя Рэя Бредбери есть роман «451 градус по Фаренгейту». Напишите программу, которая определяет, какой температуре по шкале Цельсия соответствует указанное значение по шкале Фаренгейта.
#
# Используйте формулу для перевода:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Задача 21: Дано положительное действительное число. Выведите его первую цифру после десятичной точки. Никаких дополнительных функций (кроме int()) для округления не использовать.

# %%
cgjkmpjdfnm

# %% [markdown]
# Задача 22: Вводим сумму без налогов и считаем сумму с налогами (13%)

# %% [markdown]
# Задача 23: Как известно, целые числа в языке Python не имеют ограничений, которые встречаются в других языках программирования. Напишите программу, которая считывает четыре целых положительных числа a,b,c и d и выводит на экран значение выражения
#
# ![image.png](data:image/png;base64,...)
